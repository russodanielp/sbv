# %% [markdown]
# # svb IMPROVER SysTox Challenge -  Challenge one

# %%
import pandas as pd

# %%
X = pd.read_table(r'sc1_subset2\dataset_test_sc1_subset2.txt', sep='\t', index_col=0).T
labels = pd.read_table(r'sc1_subset2\metadata_test_sc1_subset2.txt', sep='\t')

# %%
X.head()
# Out:
#                       A1BG       A2M      NAT1      NAT2  SERPINA3     AADAC  \
# S_pnGrbEcfMB.CEL  5.440168  4.780227  5.952923  4.123119  3.847653  4.081755
# S_wZHUxEtMLL.CEL  5.211873  5.288823  7.369128  3.600873  4.171189  3.849617
# S_QfWhwAB9nj.CEL  5.507919  4.765083  6.271740  3.771244  4.060384  4.117754
# S_UftmLINKwJ.CEL  5.705496  4.848514  5.770588  3.555282  3.994904  3.661336
# S_msbnGQ4g4s.CEL  5.596749  5.307721  6.706592  3.999862  3.763852  3.351099
#
#                       AAMP     AANAT      AARS      ABAT    ...     \
# S_pnGrbEcfMB.CEL  6.755132  4.163015  6.871324  7.740349    ...
# S_wZHUxEtMLL.CEL  7.079216  4.043423  6.712434  7.980125    ...
# S_QfWhwAB9nj.CEL  6.897427  3.937694  7.234308  7.028576    ...
# S_UftmLINKwJ.CEL  6.758115  3.947332  7.329091  7.614971    ...
# S_msbnGQ4g4s.CEL  6.756973  3.696436  6.958547  7.310985    ...
#
#                   GS1-24F4.2  LOC100652824  LINC01023  LINC00408  \
# ...

# %%
labels.set_index('rname').head()
# Out:
#                  Gender
# rname
# S_pnGrbEcfMB.CEL      M
# S_wZHUxEtMLL.CEL      F
# S_QfWhwAB9nj.CEL      M
# S_UftmLINKwJ.CEL      M
# S_msbnGQ4g4s.CEL      F
